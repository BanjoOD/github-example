# %% [markdown]
# # Coursera Capstone Project

# %%
#import required libraries
import pandas as pd
from bs4 import BeautifulSoup as bsp
import requests

# %%
#use requests to 'get'the url text
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

#pass this source (and lxml) to BeautifulSoup
soup = bsp(source, 'lxml')

#scrape the webpage for the table of canada neighbourhoods
table = soup.find('table', class_='wikitable sortable')

#collect the table column titles into a list
table_columns = []
for th in table.find_all('th'):
    table_columns.append(th.text)

# %%
# replace the 'Neighbourhood\n' in the list with 'Neighbourhood'
table_columns[2] = 'Neighbourhood'
table_columns
# Out:
# ['Postcode', 'Borough', 'Neighbourhood']

# %%
# collect the table row values into a row of lists 
output_rows = []
for table_row in table.find_all('tr'): # find all tr -> table rows
    columns =  table_row.find_all('td') # within each row, find all table data belonging to that row
    output_row = []
    for column in columns:
         output_row.append(column.text) # append each data to its column 
    output_rows.append(output_row) #append each row to its row

# %%
can_df = pd.DataFrame(output_rows)

# %%
can_df.columns = table_columns
can_df.drop([0], axis = 0, inplace=True)

# %%
can_df.iloc[:, 2].head(5)
# Out:
# 1        Not assigned\n
# 2        Not assigned\n
# 3           Parkwoods\n
# 4    Victoria Village\n
# 5        Harbourfront\n
# Name: Neighbourhood, dtype: object

# %%
# the values in Neighbourhood column need to be stripped of '\n' special character
can_df['Neighbourhood'] = can_df['Neighbourhood'].map(lambda x:str(x)[:-1])

# %%
can_df.head(10)
# Out:
#    Postcode           Borough     Neighbourhood
# 1       M1A      Not assigned      Not assigned
# 2       M2A      Not assigned      Not assigned
# 3       M3A        North York         Parkwoods
# 4       M4A        North York  Victoria Village
# 5       M5A  Downtown Toronto      Harbourfront
# 6       M5A  Downtown Toronto       Regent Park
# 7       M6A        North York  Lawrence Heights
# 8       M6A        North York    Lawrence Manor
# 9       M7A      Queen's Park      Not assigned
# 10      M8A      Not assigned      Not assigned

# %%
can_df.shape[0]
# Out:
# 288

# %%
# some Postcodes have Boroughs but neighbourhood 'Not assigned'
# assign to a Neighbourhood with 'Not Assigned' the value of it's Borough 
for i in range(can_df.shape[0]):
    if (can_df.iloc[i,1] !='Not assigned') & (can_df.iloc[i,2] == 'Not assigned'):
        can_df.iloc[i,2] = can_df.iloc[i,1]

# %%
can_df.head(10)
# Out:
#    Postcode           Borough     Neighbourhood
# 1       M1A      Not assigned      Not assigned
# 2       M2A      Not assigned      Not assigned
# 3       M3A        North York         Parkwoods
# 4       M4A        North York  Victoria Village
# 5       M5A  Downtown Toronto      Harbourfront
# 6       M5A  Downtown Toronto       Regent Park
# 7       M6A        North York  Lawrence Heights
# 8       M6A        North York    Lawrence Manor
# 9       M7A      Queen's Park      Queen's Park
# 10      M8A      Not assigned      Not assigned

# %%
# some boroughs have the same postcodes but different neighbourhoods
# group together these boroughs based on Postcodes and aggregate the values of their neighbourhood
aggregate_func = {'Borough':'first', 'Neighbourhood': lambda x: ', '.join(x)}
can_df_new = can_df.groupby(can_df['Postcode']).aggregate(aggregate_func)

# %%
can_df_new
# Out:
#                Borough                                      Neighbourhood
# Postcode
# M1A       Not assigned                                       Not assigned
# M1B        Scarborough                                     Rouge, Malvern
# M1C        Scarborough             Highland Creek, Rouge Hill, Port Union
# M1E        Scarborough                  Guildwood, Morningside, West Hill
# M1G        Scarborough                                             Woburn
# M1H        Scarborough                                          Cedarbrae
# M1J        Scarborough                                Scarborough Village
# M1K        Scarborough        East Birchmount Park, Ionview, Kennedy Park
# M1L        Scarborough                    Clairlea, Golden Mile, Oakridge
# M1M        Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# M1N        Scarborough                        Birch Cliff, Cliffside West
# M1P        Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# M1R        Scarborough                                  Maryvale, Wexford
# M1S        Scarborough                                          Agincourt
# M1T        Scarborough            Clarks Corners, Sullivan, Tam O'Shanter
# M1V        Scarborough  Agincourt North, L'Amoreaux East, Milliken, St...
# M1W        Scarborough                                    L'Amoreaux West
# M1X        Scarborough                                        Upper Rouge
# M1Y       Not assigned                                       Not assigned
# M1Z       Not assigned                                       Not assigned
# M2A       Not assigned                                       Not assigned
# M2B       Not assigned                                       Not assigned
# M2C       Not assigned                                       Not assigned
# M2E       Not assigned                                       Not assigned
# M2G       Not assigned                                       Not assigned
# M2H         North York                                  Hillcrest Village
# M2J         North York                       Fairview, Henry Farm, Oriole
# M2K         North York                                    Bayview Village
# M2L         North York                           Silver Hills, York Mills
# M2M         North York                            Newtonbrook, Willowdale
# ...                ...                                                ...
# M8N       Not assigned                                       Not assigned
# M8P       Not assigned                                       Not assigned
# M8R       Not assigned                                       Not assigned
# M8S       Not assigned                                       Not assigned
# M8T       Not assigned                                       Not assigned
# M8V          Etobicoke       Humber Bay Shores, Mimico South, New Toronto
# M8W          Etobicoke                             Alderwood, Long Branch
# M8X          Etobicoke      The Kingsway, Montgomery Road, Old Mill North
# M8Y          Etobicoke  Humber Bay, King's Mill Park, Kingsway Park So...
# M8Z          Etobicoke  Kingsway Park South West, Mimico NW, The Queen...
# M9A          Etobicoke                                   Islington Avenue
# M9B          Etobicoke  Cloverdale, Islington, Martin Grove, Princess ...
# M9C          Etobicoke  Bloordale Gardens, Eringate, Markland Wood, Ol...
# M9E       Not assigned                                       Not assigned
# M9G       Not assigned                                       Not assigned
# M9H       Not assigned                                       Not assigned
# M9J       Not assigned                                       Not assigned
# M9K       Not assigned                                       Not assigned
# M9L         North York                                      Humber Summit
# M9M         North York                                   Emery, Humberlea
# M9N               York                                             Weston
# M9P          Etobicoke                                          Westmount
# M9R          Etobicoke  Kingsview Village, Martin Grove Gardens, Richv...
# M9S       Not assigned                                       Not assigned
# M9T       Not assigned                                       Not assigned
# M9V          Etobicoke  Albion Gardens, Beaumond Heights, Humbergate, ...
# M9W          Etobicoke                                          Northwest
# M9X       Not assigned                                       Not assigned
# M9Y       Not assigned                                       Not assigned
# M9Z       Not assigned                                       Not assigned
#
# [180 rows x 2 columns]

# %%
#reset index
can_df_new.reset_index(inplace=True)
can_df_new.shape
# Out:
# (180, 3)

# %%
# we need to the Postodes with Borough 'Not assigned'
#But first we must collect their indices
drop_list = []
for i in range(can_df_new.shape[0]):
    if can_df_new.iloc[i,1] == 'Not assigned':
        drop_list.append(i)
drop_list[0:9]
# Out:
# [0, 18, 19, 20, 21, 22, 23, 24, 33]

# %%
# drop these rows
can_df_new.drop(drop_list, axis=0, inplace=True)

# %%
# reset index to make the count start from 0
can_df_new.reset_index(inplace=True)
can_df_new.head(5)
# Out:
#    index Postcode      Borough                           Neighbourhood
# 0      1      M1B  Scarborough                          Rouge, Malvern
# 1      2      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2      3      M1E  Scarborough       Guildwood, Morningside, West Hill
# 3      4      M1G  Scarborough                                  Woburn
# 4      5      M1H  Scarborough                               Cedarbrae

# %%
# Let's drop the 'index' column
can_df_new.drop(['index'], axis=1, inplace=True)

# %%
# finally our toronto neighbourhood!!!
tor_neighbor = can_df_new
tor_neighbor.head(15)
# Out:
#    Postcode      Borough                                      Neighbourhood
# 0       M1B  Scarborough                                     Rouge, Malvern
# 1       M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2       M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3       M1G  Scarborough                                             Woburn
# 4       M1H  Scarborough                                          Cedarbrae
# 5       M1J  Scarborough                                Scarborough Village
# 6       M1K  Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 7       M1L  Scarborough                    Clairlea, Golden Mile, Oakridge
# 8       M1M  Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# 9       M1N  Scarborough                        Birch Cliff, Cliffside West
# 10      M1P  Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 11      M1R  Scarborough                                  Maryvale, Wexford
# 12      M1S  Scarborough                                          Agincourt
# 13      M1T  Scarborough            Clarks Corners, Sullivan, Tam O'Shanter
# 14      M1V  Scarborough  Agincourt North, L'Amoreaux East, Milliken, St...

# %%
tor_neighbor.shape
# Out:
# (103, 3)

# %%
lat_lng_coords = pd.read_csv('~/Desktop/projects/github-example/Geospatial_Coordinates.csv')

# %%
lat_lng_coords.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
tor_neighbor[['Latitude', 'Longitude']] = lat_lng_coords[['Latitude', 'Longitude']]

# %%
tor_neighbor.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::numba==0.43.1=py37h962f231_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/emperor/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     babel-2.7.0                |             py_0         5.8 MB
#     bzip2-1.0.8                |       h7b6447c_0         105 KB
#     chardet-3.0.4              |        py37_1003         173 KB
#     cloudpickle-1.2.2          |             py_0          29 KB
#     cryptography-2.7           |   py37h1ba5d50_0         608 KB
#     defusedxml-0.6.0           |             py_0          23 KB
#     docutils-0.15.2            |           py37_0         736 KB
#     filelock-3.0.12            |             py_0          12 KB
#     glob2-0.7                  |             py_0          14 KB
#     intel-openmp-2019.4        |              243         876 KB
#     ipykernel-5.1.2            |   py37h39e3cac_0         165 KB
#     ipython-7.8.0              |   py37h39e3cac_0         1.1 MB
#     ipywidgets-7.5.1           |             py_0         107 KB
#     isort-4.3.21               |           py37_0          68 KB
#     jedi-0.15.1                |           py37_0         713 KB
#     jeepney-0.4.1              |             py_0          21 KB
#     jinja2-2.10.1              |           py37_0         188 KB
#     json5-0.8.5                |             py_0          25 KB
#     jsonschema-3.0.2           |           py37_0          91 KB
#     jupyter_client-5.3.3       |           py37_1         137 KB
#     jupyter_core-4.5.0         |             py_0          48 KB
#     jupyterlab-1.1.4           |     pyhf63ae98_0        11.7 MB
#     jupyterlab_server-1.0.6    |             py_0          26 KB
#     lazy-object-proxy-1.4.2    |   py37h7b6447c_0          30 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     libxml2-2.9.9              |       hea5a465_1         2.0 MB
#     mkl-2019.4                 |              243       204.1 MB
#     mkl-service-2.3.0          |   py37he904b0f_0         208 KB
#     mkl_fft-1.0.14             |   py37ha843d7b_0         172 KB
#     mkl_random-1.1.0           |   py37hd6b4f25_0         376 KB
#     nbconvert-5.6.0            |           py37_1         491 KB
#     notebook-6.0.1             |           py37_0         6.0 MB
#     numpy-1.16.5               |   py37h7e9f1db_0          49 KB
#     numpy-base-1.16.5          |   py37hde5b4d6_0         4.4 MB
#     packaging-19.2             |             py_0          30 KB
#     parso-0.5.1                |             py_0          68 KB
#     pexpect-4.7.0              |           py37_0          82 KB
#     pillow-6.1.0               |   py37h34e0f95_0         635 KB
#     pip-19.2.3                 |           py37_0         1.9 MB
#     prometheus_client-0.7.1    |             py_0          42 KB
#     psutil-5.6.3               |   py37h7b6447c_0         328 KB
#     pygments-2.4.2             |             py_0         664 KB
#     pyparsing-2.4.2            |             py_0          61 KB
#     pyrsistent-0.15.4          |   py37h7b6447c_0          92 KB
#     pysocks-1.7.1              |           py37_0          30 KB
#     python-libarchive-c-2.8    |          py37_13          23 KB
#     pytz-2019.2                |             py_0         245 KB
#     pyyaml-5.1.2               |   py37h7b6447c_0         189 KB
#     pyzmq-18.1.0               |   py37he6710b0_0         498 KB
#     qtawesome-0.6.0            |             py_0         671 KB
#     qtconsole-4.5.5            |             py_0          94 KB
#     qtpy-1.9.0                 |             py_0          39 KB
#     requests-2.22.0            |           py37_0          89 KB
#     setuptools-41.2.0          |           py37_0         630 KB
#     snowballstemmer-1.9.1      |             py_0          59 KB
#     soupsieve-1.9.3            |           py37_0          60 KB
#     sphinx-2.2.0               |             py_0         1.5 MB
#     spyder-kernels-0.5.2       |           py37_0          69 KB
#     sqlite-3.29.0              |       h7b6447c_0         1.9 MB
#     tbb-2019.4                 |       hfd86e86_0         1.4 MB
#     terminado-0.8.2            |           py37_0          22 KB
#     tornado-6.0.3              |   py37h7b6447c_0         644 KB
#     tqdm-4.36.1                |             py_0          50 KB
#     wheel-0.33.6               |           py37_0          40 KB
#     widgetsnbextension-3.5.1   |           py37_0         1.8 MB
#     wrapt-1.11.2               |   py37h7b6447c_0          49 KB
#     wurlitzer-1.0.3            |           py37_0          14 KB
#     ------------------------------------------------------------
#                                            Total:       266.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   json5              pkgs/main/noarch::json5-0.8.5-py_0
#   sphinxcontrib-app~ pkgs/main/noarch::sphinxcontrib-applehelp-1.0.1-py_0
#   sphinxcontrib-dev~ pkgs/main/noarch::sphinxcontrib-devhelp-1.0.1-py_0
#   sphinxcontrib-htm~ pkgs/main/noarch::sphinxcontrib-htmlhelp-1.0.2-py_0
#   sphinxcontrib-jsm~ pkgs/main/noarch::sphinxcontrib-jsmath-1.0.1-py_0
#   sphinxcontrib-qth~ pkgs/main/noarch::sphinxcontrib-qthelp-1.0.2-py_0
#   sphinxcontrib-ser~ pkgs/main/noarch::sphinxcontrib-serializinghtml-1.1.3-py_0
#   tbb                pkgs/main/linux-64::tbb-2019.4-hfd86e86_0
#
# The following packages will be UPDATED:
#
#   babel              pkgs/main/linux-64::babel-2.6.0-py37_0 --> pkgs/main/noarch::babel-2.7.0-py_0
#   beautifulsoup4                               4.7.1-py37_1 --> 4.8.0-py37_0
#   bzip2                                    1.0.6-h14c3975_5 --> 1.0.8-h7b6447c_0
#   cffi                                1.12.2-py37h2e261b9_1 --> 1.12.3-py37h2e261b9_0
#   chardet                                      3.0.4-py37_1 --> 3.0.4-py37_1003
#   cloudpickle        pkgs/main/linux-64::cloudpickle-0.8.0~ --> pkgs/main/noarch::cloudpickle-1.2.2-py_0
#   cryptography                         2.6.1-py37h1ba5d50_0 --> 2.7-py37h1ba5d50_0
#   defusedxml         pkgs/main/linux-64::defusedxml-0.5.0-~ --> pkgs/main/noarch::defusedxml-0.6.0-py_0
#   docutils                                      0.14-py37_0 --> 0.15.2-py37_0
#   filelock           pkgs/main/linux-64::filelock-3.0.10-p~ --> pkgs/main/noarch::filelock-3.0.12-py_0
#   glob2                pkgs/main/linux-64::glob2-0.6-py37_1 --> pkgs/main/noarch::glob2-0.7-py_0
#   intel-openmp                                   2019.3-199 --> 2019.4-243
#   ipykernel                            5.1.0-py37h39e3cac_0 --> 5.1.2-py37h39e3cac_0
#   ipython                              7.4.0-py37h39e3cac_0 --> 7.8.0-py37h39e3cac_0
#   ipywidgets         pkgs/main/linux-64::ipywidgets-7.4.2-~ --> pkgs/main/noarch::ipywidgets-7.5.1-py_0
#   isort                                       4.3.16-py37_0 --> 4.3.21-py37_0
#   jedi                                        0.13.3-py37_0 --> 0.15.1-py37_0
#   jeepney            pkgs/main/linux-64::jeepney-0.4-py37_0 --> pkgs/main/noarch::jeepney-0.4.1-py_0
#   jinja2                                        2.10-py37_0 --> 2.10.1-py37_0
#   jsonschema                                   3.0.1-py37_0 --> 3.0.2-py37_0
#   jupyter_client                               5.2.4-py37_0 --> 5.3.3-py37_1
#   jupyter_core       pkgs/main/linux-64::jupyter_core-4.4.~ --> pkgs/main/noarch::jupyter_core-4.5.0-py_0
#   jupyterlab         pkgs/main/linux-64::jupyterlab-0.35.4~ --> pkgs/main/noarch::jupyterlab-1.1.4-pyhf63ae98_0
#   jupyterlab_server  pkgs/main/linux-64::jupyterlab_server~ --> pkgs/main/noarch::jupyterlab_server-1.0.6-py_0
#   lazy-object-proxy                    1.3.1-py37h14c3975_2 --> 1.4.2-py37h7b6447c_0
#   libgcc-ng                                8.2.0-hdf63c60_1 --> 9.1.0-hdf63c60_0
#   libpng                                  1.6.36-hbc83047_0 --> 1.6.37-hbc83047_0
#   libstdcxx-ng                             8.2.0-hdf63c60_1 --> 9.1.0-hdf63c60_0
#   libxml2                                  2.9.9-he19cac6_0 --> 2.9.9-hea5a465_1
#   mkl                                            2019.3-199 --> 2019.4-243
#   mkl-service                          1.1.2-py37he904b0f_5 --> 2.3.0-py37he904b0f_0
#   mkl_fft                             1.0.10-py37ha843d7b_0 --> 1.0.14-py37ha843d7b_0
#   mkl_random                           1.0.2-py37hd81dba3_0 --> 1.1.0-py37hd6b4f25_0
#   nbconvert                                    5.4.1-py37_3 --> 5.6.0-py37_1
#   notebook                                     5.7.8-py37_0 --> 6.0.1-py37_0
#   numpy                               1.16.2-py37h7e9f1db_0 --> 1.16.5-py37h7e9f1db_0
#   numpy-base                          1.16.2-py37hde5b4d6_0 --> 1.16.5-py37hde5b4d6_0
#   numpydoc           pkgs/main/linux-64::numpydoc-0.8.0-py~ --> pkgs/main/noarch::numpydoc-0.9.1-py_0
#   packaging          pkgs/main/linux-64::packaging-19.0-py~ --> pkgs/main/noarch::packaging-19.2-py_0
#   parso              pkgs/main/linux-64::parso-0.3.4-py37_0 --> pkgs/main/noarch::parso-0.5.1-py_0
#   pexpect                                      4.6.0-py37_0 --> 4.7.0-py37_0
#   pillow                               5.4.1-py37h34e0f95_0 --> 6.1.0-py37h34e0f95_0
#   pip                                         19.0.3-py37_0 --> 19.2.3-py37_0
#   prometheus_client  pkgs/main/linux-64::prometheus_client~ --> pkgs/main/noarch::prometheus_client-0.7.1-py_0
#   psutil                               5.6.1-py37h7b6447c_0 --> 5.6.3-py37h7b6447c_0
#   pygments           pkgs/main/linux-64::pygments-2.3.1-py~ --> pkgs/main/noarch::pygments-2.4.2-py_0
#   pyparsing          pkgs/main/linux-64::pyparsing-2.3.1-p~ --> pkgs/main/noarch::pyparsing-2.4.2-py_0
#   pyrsistent                         0.14.11-py37h7b6447c_0 --> 0.15.4-py37h7b6447c_0
#   pysocks                                      1.6.8-py37_0 --> 1.7.1-py37_0
#   python-libarchive~                             2.8-py37_6 --> 2.8-py37_13
#   pytz               pkgs/main/linux-64::pytz-2018.9-py37_0 --> pkgs/main/noarch::pytz-2019.2-py_0
#   pyyaml                                 5.1-py37h7b6447c_0 --> 5.1.2-py37h7b6447c_0
#   pyzmq                               18.0.0-py37he6710b0_0 --> 18.1.0-py37he6710b0_0
#   qtawesome          pkgs/main/linux-64::qtawesome-0.5.7-p~ --> pkgs/main/noarch::qtawesome-0.6.0-py_0
#   qtconsole          pkgs/main/linux-64::qtconsole-4.4.3-p~ --> pkgs/main/noarch::qtconsole-4.5.5-py_0
#   qtpy                pkgs/main/linux-64::qtpy-1.7.0-py37_1 --> pkgs/main/noarch::qtpy-1.9.0-py_0
#   requests                                    2.21.0-py37_0 --> 2.22.0-py37_0
#   rope               pkgs/main/linux-64::rope-0.12.0-py37_0 --> pkgs/main/noarch::rope-0.14.0-py_0
#   setuptools                                  40.8.0-py37_0 --> 41.2.0-py37_0
#   snowballstemmer    pkgs/main/linux-64::snowballstemmer-1~ --> pkgs/main/noarch::snowballstemmer-1.9.1-py_0
#   soupsieve                                      1.8-py37_0 --> 1.9.3-py37_0
#   sphinx             pkgs/main/linux-64::sphinx-1.8.5-py37~ --> pkgs/main/noarch::sphinx-2.2.0-py_0
#   spyder-kernels                               0.4.4-py37_0 --> 0.5.2-py37_0
#   sqlite                                  3.27.2-h7b6447c_0 --> 3.29.0-h7b6447c_0
#   terminado                                    0.8.1-py37_1 --> 0.8.2-py37_0
#   tornado                              6.0.2-py37h7b6447c_0 --> 6.0.3-py37h7b6447c_0
#   tqdm               pkgs/main/linux-64::tqdm-4.31.1-py37_1 --> pkgs/main/noarch::tqdm-4.36.1-py_0
#   urllib3                                     1.24.1-py37_0 --> 1.24.2-py37_0
#   wheel                                       0.33.1-py37_0 --> 0.33.6-py37_0
#   widgetsnbextension                           3.4.2-py37_0 --> 3.5.1-py37_0
#   wrapt                               1.11.1-py37h7b6447c_0 --> 1.11.2-py37h7b6447c_0
#   wurlitzer                                    1.0.2-py37_0 --> 1.0.3-py37_0
#
#
#
# Downloading and Extracting Packages
# pytz-2019.2          | 245 KB    | ##################################### | 100%
# cryptography-2.7     | 608 KB    | ##################################### | 100%
# soupsieve-1.9.3      | 60 KB     | ##################################### | 100%
# packaging-19.2       | 30 KB     | ##################################### | 100%
# bzip2-1.0.8          | 105 KB    | ##################################### | 100%
# nbconvert-5.6.0      | 491 KB    | ##################################### | 100%
# ipywidgets-7.5.1     | 107 KB    | ##################################### | 100%
# psutil-5.6.3         | 328 KB    | ##################################### | 100%
# libxml2-2.9.9        | 2.0 MB    | ##################################### | 100%
# spyder-kernels-0.5.2 | 69 KB     | ##################################### | 100%
# pexpect-4.7.0        | 82 KB     | ##################################### | 100%
# json5-0.8.5          | 25 KB     | ##################################### | 100%
# jinja2-2.10.1        | 188 KB    | ##################################### | 100%
# docutils-0.15.2      | 736 KB    | ##################################### | 100%
# sqlite-3.29.0        | 1.9 MB    | ##################################### | 100%
# jeepney-0.4.1        | 21 KB     | ##################################### | 100%
# jupyter_core-4.5.0   | 48 KB     | ##################################### | 100%
# lazy-object-proxy-1. | 30 KB     | ##################################### | 100%
# notebook-6.0.1       | 6.0 MB    | ##################################### | 100%
# isort-4.3.21         | 68 KB     | ##################################### | 100%
# terminado-0.8.2      | 22 KB     | ##################################### | 100%
# pyyaml-5.1.2         | 189 KB    | ##################################### | 100%
# jupyter_client-5.3.3 | 137 KB    | ##################################### | 100%
# jupyterlab_server-1. | 26 KB     | ##################################### | 100%
# pyrsistent-0.15.4    | 92 KB     | ##################################### | 100%
# pyzmq-18.1.0         | 498 KB    | ##################################### | 100%
# jsonschema-3.0.2     | 91 KB     | ##################################### | 100%
# qtpy-1.9.0           | 39 KB     | ##################################### | 100%
# tornado-6.0.3        | 644 KB    | ##################################### | 100%
# tqdm-4.36.1          | 50 KB     | ##################################### | 100%
# prometheus_client-0. | 42 KB     | ##################################### | 100%
# jedi-0.15.1          | 713 KB    | ##################################### | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ##################################### | 100%
# ipykernel-5.1.2      | 165 KB    | ##################################### | 100%
# defusedxml-0.6.0     | 23 KB     | ##################################### | 100%
# numpy-base-1.16.5    | 4.4 MB    | ##################################### | 100%
# intel-openmp-2019.4  | 876 KB    | ##################################### | 100%
# snowballstemmer-1.9. | 59 KB     | ##################################### | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ##################################### | 100%
# pyparsing-2.4.2      | 61 KB     | ##################################### | 100%
# requests-2.22.0      | 89 KB     | ##################################### | 100%
# sphinx-2.2.0         | 1.5 MB    | ##################################### | 100%
# parso-0.5.1          | 68 KB     | ##################################### | 100%
# mkl-2019.4           | 204.1 MB  | ##################################### | 100%
# python-libarchive-c- | 23 KB     | ##################################### | 100%
# wheel-0.33.6         | 40 KB     | ##################################### | 100%
# ipython-7.8.0        | 1.1 MB    | ##################################### | 100%
# mkl_fft-1.0.14       | 172 KB    | ##################################### | 100%
# mkl_random-1.1.0     | 376 KB    | ##################################### | 100%
# babel-2.7.0          | 5.8 MB    | ##################################### | 100%
# pillow-6.1.0         | 635 KB    | ##################################### | 100%
# qtawesome-0.6.0      | 671 KB    | ##################################### | 100%
# numpy-1.16.5         | 49 KB     | ##################################### | 100%
# filelock-3.0.12      | 12 KB     | ##################################### | 100%
# setuptools-41.2.0    | 630 KB    | ##################################### | 100%
# pysocks-1.7.1        | 30 KB     | ##################################### | 100%
# qtconsole-4.5.5      | 94 KB     | ##################################### | 100%
# tbb-2019.4           | 1.4 MB    | ##################################### | 100%
# wurlitzer-1.0.3      | 14 KB     | ##################################### | 100%
# pip-19.2.3           | 1.9 MB    | ##################################### | 100%
# mkl-service-2.3.0    | 208 KB    | ##################################### | 100%
# jupyterlab-1.1.4     | 11.7 MB   | ##################################### | 100%
# glob2-0.7            | 14 KB     | ##################################### | 100%
# pygments-2.4.2       | 664 KB    | ##################################### | 100%
# wrapt-1.11.2         | 49 KB     | ##################################### | 100%
# chardet-3.0.4        | 173 KB    | ##################################### | 100%
# widgetsnbextension-3 | 1.8 MB    | ##################################### | 100%
# cloudpickle-1.2.2    | 29 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(tor_neighbor['Borough'].unique()),
        tor_neighbor.shape[0]
    )
)
# Out:
# The dataframe has 11 boroughs and 103 neighborhoods.

# %%
tor_neighbor['Borough'].unique()
# Out:
# array(['Scarborough', 'North York', 'East York', 'East Toronto',
#        'Central Toronto', 'Downtown Toronto', 'York', 'West Toronto',
#        "Queen's Park", 'Mississauga', 'Etobicoke'], dtype=object)

# %%
Toronto_data = tor_neighbor[tor_neighbor['Borough'].str.endswith('Toronto')]

# %%
Toronto_data.head()
# Out:
#    Postcode          Borough                   Neighbourhood   Latitude  \
# 37      M4E     East Toronto                     The Beaches  43.676357
# 41      M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 42      M4L     East Toronto  The Beaches West, India Bazaar  43.668999
# 43      M4M     East Toronto                 Studio District  43.659526
# 44      M4N  Central Toronto                   Lawrence Park  43.728020
#
#     Longitude
# 37 -79.293031
# 41 -79.352188
# 42 -79.315572
# 43 -79.340923
# 44 -79.388790

# %%
Toronto_data.reset_index(inplace=True)

# %%
Toronto_data.drop(['index'], axis=1, inplace=True)
# Out:
# /home/emperor/anaconda3/envs/tensorflow/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
Toronto_data
# Out:
#    Postcode           Borough  \
# 0       M4E      East Toronto
# 1       M4K      East Toronto
# 2       M4L      East Toronto
# 3       M4M      East Toronto
# 4       M4N   Central Toronto
# 5       M4P   Central Toronto
# 6       M4R   Central Toronto
# 7       M4S   Central Toronto
# 8       M4T   Central Toronto
# 9       M4V   Central Toronto
# 10      M4W  Downtown Toronto
# 11      M4X  Downtown Toronto
# 12      M4Y  Downtown Toronto
# 13      M5A  Downtown Toronto
# 14      M5B  Downtown Toronto
# 15      M5C  Downtown Toronto
# 16      M5E  Downtown Toronto
# 17      M5G  Downtown Toronto
# 18      M5H  Downtown Toronto
# 19      M5J  Downtown Toronto
# 20      M5K  Downtown Toronto
# 21      M5L  Downtown Toronto
# 22      M5N   Central Toronto
# 23      M5P   Central Toronto
# 24      M5R   Central Toronto
# 25      M5S  Downtown Toronto
# 26      M5T  Downtown Toronto
# 27      M5V  Downtown Toronto
# 28      M5W  Downtown Toronto
# 29      M5X  Downtown Toronto
# 30      M6G  Downtown Toronto
# 31      M6H      West Toronto
# 32      M6J      West Toronto
# 33      M6K      West Toronto
# 34      M6P      West Toronto
# 35      M6R      West Toronto
# 36      M6S      West Toronto
# 37      M7Y      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                         The Beaches  43.676357 -79.293031
# 1                        The Danforth West, Riverdale  43.679557 -79.352188
# 2                      The Beaches West, India Bazaar  43.668999 -79.315572
# 3                                     Studio District  43.659526 -79.340923
# 4                                       Lawrence Park  43.728020 -79.388790
# 5                                    Davisville North  43.712751 -79.390197
# 6                                  North Toronto West  43.715383 -79.405678
# 7                                          Davisville  43.704324 -79.388790
# 8                         Moore Park, Summerhill East  43.689574 -79.383160
# 9   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 10                                           Rosedale  43.679563 -79.377529
# 11                        Cabbagetown, St. James Town  43.667967 -79.367675
# 12                               Church and Wellesley  43.665860 -79.383160
# 13                          Harbourfront, Regent Park  43.654260 -79.360636
# 14                           Ryerson, Garden District  43.657162 -79.378937
# 15                                     St. James Town  43.651494 -79.375418
# 16                                        Berczy Park  43.644771 -79.373306
# 17                                 Central Bay Street  43.657952 -79.387383
# 18                           Adelaide, King, Richmond  43.650571 -79.384568
# 19  Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 20           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 21                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 22                                           Roselawn  43.711695 -79.416936
# 23                Forest Hill North, Forest Hill West  43.696948 -79.411307
# 24                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 25                     Harbord, University of Toronto  43.662696 -79.400049
# 26          Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 27  CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 28                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 29             First Canadian Place, Underground city  43.648429 -79.382280
# 30                                           Christie  43.669542 -79.422564
# 31                       Dovercourt Village, Dufferin  43.669005 -79.442259
# 32                           Little Portugal, Trinity  43.647927 -79.419750
# 33       Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 34                      High Park, The Junction South  43.661608 -79.464763
# 35                             Parkdale, Roncesvalles  43.648960 -79.456325
# 36                                 Runnymede, Swansea  43.651571 -79.484450
# 37  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="ont_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Toronto are 43.653963, -79.387207.

# %%
# one hot encoding
Toronto_onehot = pd.get_dummies(Toronto_data[['Borough']], prefix="", prefix_sep="")

# add borough column back to dataframe
Toronto_onehot['Borough'] = Toronto_data['Borough'] 

# move neighborhood column to the first column
fixed_columns = [Toronto_onehot.columns[-1]] + list(Toronto_onehot.columns[:-1])
Toronto_onehot = Toronto_onehot[fixed_columns]

Toronto_onehot.head()
# Out:
#            Borough  Central Toronto  Downtown Toronto  East Toronto  \
# 0     East Toronto                0                 0             1
# 1     East Toronto                0                 0             1
# 2     East Toronto                0                 0             1
# 3     East Toronto                0                 0             1
# 4  Central Toronto                1                 0             0
#
#    West Toronto
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
Toronto_grouped = Toronto_data.groupby('Borough').mean().reset_index()
Toronto_grouped
# Out:
#             Borough   Latitude  Longitude
# 0   Central Toronto  43.701980 -79.398954
# 1  Downtown Toronto  43.654169 -79.383665
# 2      East Toronto  43.669436 -79.324654
# 3      West Toronto  43.652653 -79.449290

# %%
# set number of clusters
kclusters = 4

Toronto_grouped_clustering = Toronto_onehot.drop('Borough', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:5]
# Out:
# array([0, 0, 0, 0, 2], dtype=int32)

# %%
# add clustering labels
Toronto_data.insert(5, 'Cluster Labels', kmeans.labels_)

Toronto_data.head() # check the last columns!
# Out:
#   Postcode          Borough                   Neighbourhood   Latitude  \
# 0      M4E     East Toronto                     The Beaches  43.676357
# 1      M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2      M4L     East Toronto  The Beaches West, India Bazaar  43.668999
# 3      M4M     East Toronto                 Studio District  43.659526
# 4      M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude  Cluster Labels
# 0 -79.293031               0
# 1 -79.352188               0
# 2 -79.315572               0
# 3 -79.340923               0
# 4 -79.388790               2

# %%
 #create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x  for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_data['Latitude'], Toronto_data['Longitude'], Toronto_data['Borough'], Toronto_data['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
